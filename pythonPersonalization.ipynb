# %%
from pymongo import MongoClient
myclient = MongoClient('mongodb+srv://sirisak:1234@cluster0-s9y0s.mongodb.net/test?retryWrites=true&w=majority')

# %%
import pandas as pd
import numpy as np

# %%
db = myclient["test"]
records = db["posts"]

# %%
def to_list(object):
    list = {
               "title": object['title'],
                "body": object['body'],
                "type": object['type'],
                "likes": str(object['likes'])
                }    
    return list

# %%
data=pd.DataFrame(list(map(to_list, records.find())))

# %%
dups_type = pd.pivot_table(data, values='type', index=['title'], aggfunc=np.sum)
dups_type
# Out:
#                                                     type
# title
# Ant egg omelet                                       egg
# Avocado salad                                      salad
# Bacon bread with cheese sauce                     cheese
# Beef salad                                         salad
# Boiled egg                                           egg
# Carsar salad                                       salad
# Cheese ball                                       cheese
# Cheese burgers                                   burgers
# Cheese cake                                       cheese
# Cheese tart                                       cheese
# Chicken burgers                                  burgers
# Chicken mussaman                                 chicken
# Chicken stew                                        stew
# Chicken wings red sauce                          chicken
# Chicken with bell peppers                        chicken
# Chinese braised chicken                          chicken
# Cowboy caviar salad                                salad
# Curry rice with beef stew                           stew
# Curry rice with pork stew                           stew
# DONGCHIMI MUL NAENGMYEON                          noodle
# Dark chocolate veggie bite                        veggie
# Deep fried fish lemon glass                         fish
# Deep fried fish pasty                               fish
# Deep fried pork belly with fish sauce               pork
# Deep fried pork with garlic and pepper              pork
# Deluxe cheese burgers                            burgers
# Double cheese burgers                            burgers
# Double filet burgers                             burgers
# Egg benedict                                         egg
# Egg bomb                                             egg
# ...                                                  ...
# Shrimp barley and lemon stew                        stew
# Shrimp burgers                                   burgers
# Shrimp salad                                       salad
# Slow cooked pork belly with dark soy sauce          pork
# Spicy Thai Basil Chicken (Pad Krapow Gai)        chicken
# Spicy crispy catfish                                fish
# Steamed egg                                          egg
# Steamed veggie with curry paste                   veggie
# Stir fried pork belly with chili and holy basil     pork
# Strawberry Yogurt                                  sweet
# Sukiyaki with fresh veggie                        veggie
# Sweet egg floss                                    sweet
# Thai Basil Rolls with Hoisin-Peanut Sauce           pork
# Thai Chicken Burgers                             chicken
# The Best Thai Coconut Soup                          soup
# Tom Ka Gai (Coconut Chicken Soup)                chicken
# Tomatoes salad                                     salad
# Tuna fish salad                                     fish
# Vegan burger                                     burgers
# Vegetable stew                                      stew
# Veggie bread                                      veggie
# Veggie burgers                                   burgers
# Veggie noodle                                     veggie
# Veggie pizza                                      veggie
# Veggie rice bowl                                  veggie
# Veggie salad                                       salad
# Veggie soup                                       veggie
# Veggie stick deep fried                           veggie
# Veggie toast                                      veggie
# french fried cheese                               cheese
#
# [109 rows x 1 columns]

# %%
data[data['type'] == 'egg'].count()
# Out:
# body     11
# likes    11
# title    11
# type     11
# dtype: int64

# %%
data.groupby('type').count()
# Out:
#          body  likes  title
# type
# burgers    12     12     12
# cheese     10     10     10
# chicken    10     10     10
# egg        11     11     11
# fish       10     10     10
# noodle      3      3      3
# pork       12     12     12
# salad      12     12     12
# soup        3      3      3
# steak       1      1      1
# stew       10     10     10
# sweet       5      5      5
# veggie     10     10     10

# %%
data
# Out:
#                                                   body  \
# 0                                 Milk with strawberry
# 1    4 ounces dried Thai rice noodles\n1 ounce tama...
# 2    whisk, two mixing bowls, pan or griddle, veget...
# 3    2½ cups (590 milliliters) water\n1 packet of r...
# 4    2 x 28 oz. cans tomatoes - crushed or whole is...
# 5    Easier and faster it can not be done. A salmon...
# 6    1/2 cup chopped onion2 1/2 tablespoons pesto2 ...
# 7    200 g / 7 ounce dried naengmyeon noodles (Kore...
# 8    2 cups minus 2 tablespoons all-purpose flour, ...
# 9     1 1/2 cups of sugar\n 6 egg yolks\n 2 drops o...
# 10                      \nEgg, Olive oil, Fish sauce\n
# 11   1/3 cup chicken broth1 tablespoon oyster sauce...
# 12   1/2 cup Thai glutinous rice1 1/3 cups coconut ...
# 13   1 tablespoon vegetable oil2 tablespoons grated...
# 14   3/4 pound boneless, skinless chicken meat3 tab...
# 15   1 cup mayonnaise1/4 cup flaked coconut, finely...
# 16   1/2 pound medium shrimp1/2 pound pork loin1 (8...
# 17   1 or 2 cans of tuna\n1 pound fermented kimchi,...
# 18   200g / 7 ounces elbow macaroni \n50g / 1.7 oun...
# 19   3 Tbsp ketchup (also known as tomato sauce in ...
# 20                           Pork belly and fish sauce
# 21                Pork belly with chili and holy basil
# 22                             Pork belly with mustard
# 23                                   pork and muchroom
# 24                                      ramen and pork
# 25                                  Sandwich with pork
# 26                      Pork belly with dark soy sauce
# 27                                      Pork and chili
# 28                                                Pork
# 29                                     Pork and garlic
# ..                                                 ...
# 79                          Sandwich with cheese patty
# 80                                   Deep fried cheese
# 81                         Italian lasagna with cheese
# 82                              Sweet tart with cheese
# 83                          Cake that add cheese layer
# 84                              Bread bacon and cheese
# 85                              Deep fried cheese ball
# 86   This Avocado Salad from Delish.com proves avoc...
# 87                               Salad with fried fish
# 88                             Salad with grilled beef
# 89                           Salad with grilled shrimp
# 90                 This salad made from vegetable only
# 91                        Mixed fruit serve like salad
# 92                                     Salad with kiwi
# 93                                 Salad with macaroni
# 94                  Salad with crispy bread and cheese
# 95                           Salad with only vegetable
# 96                           Salad with fresh tomatoes
# 97            Steamed veggie with curry paste enjoy !!
# 98                             Bread mixed with veggie
# 99                       Toast bread with veggie toast
# 100                             Egg noodle with veggie
# 101     Pizza with cream cheese and crunchy vegetables
# 102                          Soup with fresh vegetable
# 103                         Rice with mix of vegetable
# 104              Dark chocolate combine with vegetable
# 105           Stir fried sukiyaki with fresh vegetable
# 106                         Fresh vegetable deep fried
# 107  1 pound extra-lean ground chicken\n\n½ cup Ita...
# 108                                       Vegan burger
#
#                                                  likes  \
# 0               [ObjectId('5d2f19959b09d20d4cf4320f')]
# 1    [ObjectId('5d2f1d399b09d20d4cf43216'), ObjectI...
# 2               [ObjectId('5d2f19959b09d20d4cf4320f')]
# 3                                                   []
# 4               [ObjectId('5d2f1d399b09d20d4cf43216')]
# 5                                                   []
# 6                                                   []
# 7    [ObjectId('5d2f1d399b09d20d4cf43216'), ObjectI...
# 8                                                   []
# 9                                                   []
# 10   [ObjectId('5d319a3a3f5b8b0fc4038e03'), ObjectI...
# 11                                                  []
# 12                                                  []
# 13                                                  []
# 14              [ObjectId('5d2f1d399b09d20d4cf43216')]
# 15                                                  []
# 16              [ObjectId('5d319a3a3f5b8b0fc4038e03')]
# 17              [ObjectId('5d2f1d399b09d20d4cf43216')]
# 18              [ObjectId('5d2f19959b09d20d4cf4320f')]
# 19                                                  []
# 20                                                  []
# 21                                                  []
# 22   [ObjectId('5d2f19959b09d20d4cf4320f'), ObjectI...
# 23                                                  []
# 24                                                  []
# 25                                                  []
# 26                                                  []
# 27              [ObjectId('5d2f1d399b09d20d4cf43216')]
# 28                                                  []
# 29                                                  []
# ..                                                 ...
# 79                                                  []
# 80                                                  []
# 81                                                  []
# 82                                                  []
# 83                                                  []
# 84                                                  []
# 85                                                  []
# 86                                                  []
# 87                                                  []
# 88                                                  []
# 89                                                  []
# 90                                                  []
# 91                                                  []
# 92                                                  []
# 93                                                  []
# 94                                                  []
# 95                                                  []
# 96                                                  []
# 97                                                  []
# 98                                                  []
# 99                                                  []
# 100                                                 []
# 101                                                 []
# 102                                                 []
# 103                                                 []
# 104                                                 []
# 105                                                 []
# 106                                                 []
# 107                                                 []
# 108                                                 []
#
#                                                title     type
# 0                                  Strawberry Yogurt    sweet
# 1                                Pad Thai (Udontani)   noodle
# 2                                            Pancake    sweet
# 3                                      Ramen noodles      egg
# 4                                    Lasagna (Italy)     pork
# 5                                       Salmon steak    steak
# 6                                        Pasta pesto   noodle
# 7                           DONGCHIMI MUL NAENGMYEON   noodle
# 8                                    Pastéis de Nata    sweet
# 9                                    Sweet egg floss    sweet
# 10                                        Omelet egg      egg
# 11         Spicy Thai Basil Chicken (Pad Krapow Gai)  chicken
# 12              Refined Sugar Free-Mango Sticky Rice    sweet
# 13                        The Best Thai Coconut Soup     soup
# 14                 Tom Ka Gai (Coconut Chicken Soup)  chicken
# 15                              Thai Chicken Burgers  chicken
# 16         Thai Basil Rolls with Hoisin-Peanut Sauce     pork
# 17                             Kimchi stew with tuna     soup
# 18                             KOREAN MACARONI SALAD    salad
# 19             KOREAN TOFU WITH SPICY KOREAN KETCHUP     soup
# 20             Deep fried pork belly with fish sauce     pork
# 21   Stir fried pork belly with chili and holy basil     pork
# 22       Pork belly grilled with white mustard sauce     pork
# 23                     Muchroom stir fried with pork     pork
# 24                    Ramen noodle with special pork     pork
# 25                               Sandwich fried pork     pork
# 26        Slow cooked pork belly with dark soy sauce     pork
# 27                          Nam prik with pork chops     pork
# 28                                         Pork ball     pork
# 29            Deep fried pork with garlic and pepper     pork
# ..                                               ...      ...
# 79                                   Sandwich cheese   cheese
# 80                                      Fried cheese   cheese
# 81                                    Lasagna cheese   cheese
# 82                                       Cheese tart   cheese
# 83                                       Cheese cake   cheese
# 84                     Bacon bread with cheese sauce   cheese
# 85                                       Cheese ball   cheese
# 86                                     Avocado salad    salad
# 87                                        Fish salad    salad
# 88                                        Beef salad    salad
# 89                                      Shrimp salad    salad
# 90                               Cowboy caviar salad    salad
# 91                                       Fruit salad    salad
# 92                                        Kiwi salad    salad
# 93                                    Macaroni salad    salad
# 94                                      Carsar salad    salad
# 95                                      Veggie salad    salad
# 96                                    Tomatoes salad    salad
# 97                   Steamed veggie with curry paste   veggie
# 98                                      Veggie bread   veggie
# 99                                      Veggie toast   veggie
# 100                                    Veggie noodle   veggie
# 101                                     Veggie pizza   veggie
# 102                                      Veggie soup   veggie
# 103                                 Veggie rice bowl   veggie
# 104                       Dark chocolate veggie bite   veggie
# 105                       Sukiyaki with fresh veggie   veggie
# 106                          Veggie stick deep fried   veggie
# 107                                  Chicken burgers  burgers
# 108                                     Vegan burger  burgers
#
# [109 rows x 4 columns]

# %%
data2=pd.DataFrame(list(records.find()))

# %%
data2
# Out:
#      __v                       _id advertisement  \
# 0      0  5d24f6f4884f593e74d4b399           NaN
# 1      0  5d2f16258ed63b1dcceb7002           NaN
# 2      0  5d2f191e9b09d20d4cf4320e           NaN
# 3      1  5d2f1a009b09d20d4cf43211            {}
# 4      0  5d2f1a789b09d20d4cf43213           NaN
# 5      0  5d2f1b809b09d20d4cf43215           NaN
# 6      0  5d2f1df59b09d20d4cf43218           NaN
# 7      0  5d2f1ed39b09d20d4cf4321b           NaN
# 8      0  5d2f4cbf9b09d20d4cf4321e           NaN
# 9      0  5d2f4ef69b09d20d4cf43220           NaN
# 10     0  5d319cc13f5b8b0fc4038e07           NaN
# 11     0  5d3efedd20f12936c0b6b449           NaN
# 12     0  5d3effaa20f12936c0b6b44b           NaN
# 13     0  5d3f022920f12936c0b6b44d           NaN
# 14     0  5d3f027620f12936c0b6b44f           NaN
# 15     0  5d3f02ff20f12936c0b6b451           NaN
# 16     0  5d3f03f820f12936c0b6b453           NaN
# 17     0  5d3f1a0f20f12936c0b6b457           NaN
# 18     0  5d3f1afd20f12936c0b6b459           NaN
# 19     0  5d3f1c8920f12936c0b6b45b           NaN
# 20     0  5d5d2d641c9d440000110093           NaN
# 21     0  5d5d2e871c9d440000110094           NaN
# 22     0  5d5d2edc1c9d440000110095           NaN
# 23     0  5d5d3bc81c9d44000011009e           NaN
# 24     0  5d5d3c411c9d44000011009f           NaN
# 25     0  5d5d3c781c9d4400001100a0           NaN
# 26     0  5d5d3cf71c9d4400001100a1           NaN
# 27     0  5d5d3d361c9d4400001100a2           NaN
# 28     0  5d5d3da71c9d4400001100a3           NaN
# 29     0  5d5d3dde1c9d4400001100a5           NaN
# ..   ...                       ...           ...
# 79     0  5d5d57991c9d4400001100d8           NaN
# 80     0  5d5d57cb1c9d4400001100d9           NaN
# 81     0  5d5d57e91c9d4400001100da           NaN
# 82     0  5d5d581d1c9d4400001100db           NaN
# 83     0  5d5d583a1c9d4400001100dc           NaN
# 84     0  5d5d58fa1c9d4400001100dd           NaN
# 85     0  5d5d59311c9d4400001100de           NaN
# 86     0  5d5d59fdf670cf3c883ad0f9           NaN
# 87     0  5d5d5a411c9d4400001100df           NaN
# 88     0  5d5d5a811c9d4400001100e0           NaN
# 89     0  5d5d5aa61c9d4400001100e1           NaN
# 90     0  5d5d5ac91c9d4400001100e3           NaN
# 91     0  5d5d5b521c9d4400001100e4           NaN
# 92     0  5d5d5bbf1c9d4400001100e5           NaN
# 93     0  5d5d5cbf1c9d4400001100e6           NaN
# 94     0  5d5d5cdc1c9d4400001100e7           NaN
# 95     0  5d5d5d241c9d4400001100e8           NaN
# 96     0  5d5d5d421c9d4400001100e9           NaN
# 97     0  5d5d5e8cf670cf3c883ad0fa           NaN
# 98     0  5d5d5eea1c9d4400001100ea           NaN
# 99     0  5d5d5f0a1c9d4400001100eb           NaN
# 100    0  5d5d5f491c9d4400001100ec           NaN
# 101    0  5d5d5f931c9d4400001100ed           NaN
# 102    0  5d5d5fe21c9d4400001100ee           NaN
# 103    0  5d5d60201c9d4400001100ef           NaN
# 104    0  5d5d605c1c9d4400001100f0           NaN
# 105    0  5d5d60c51c9d4400001100f1           NaN
# 106    0  5d5d61431c9d4400001100f2           NaN
# 107    0  5da73e651312a31c5847b37a           NaN
# 108    0  5da757987a7f2510cc57780d           NaN
#
#                                                   body  \
# 0                                 Milk with strawberry
# 1    4 ounces dried Thai rice noodles\n1 ounce tama...
# 2    whisk, two mixing bowls, pan or griddle, veget...
# 3    2½ cups (590 milliliters) water\n1 packet of r...
# 4    2 x 28 oz. cans tomatoes - crushed or whole is...
# 5    Easier and faster it can not be done. A salmon...
# 6    1/2 cup chopped onion2 1/2 tablespoons pesto2 ...
# 7    200 g / 7 ounce dried naengmyeon noodles (Kore...
# 8    2 cups minus 2 tablespoons all-purpose flour, ...
# 9     1 1/2 cups of sugar\n 6 egg yolks\n 2 drops o...
# 10                      \nEgg, Olive oil, Fish sauce\n
# 11   1/3 cup chicken broth1 tablespoon oyster sauce...
# 12   1/2 cup Thai glutinous rice1 1/3 cups coconut ...
# 13   1 tablespoon vegetable oil2 tablespoons grated...
# 14   3/4 pound boneless, skinless chicken meat3 tab...
# 15   1 cup mayonnaise1/4 cup flaked coconut, finely...
# 16   1/2 pound medium shrimp1/2 pound pork loin1 (8...
# 17   1 or 2 cans of tuna\n1 pound fermented kimchi,...
# 18   200g / 7 ounces elbow macaroni \n50g / 1.7 oun...
# 19   3 Tbsp ketchup (also known as tomato sauce in ...
# 20                           Pork belly and fish sauce
# 21                Pork belly with chili and holy basil
# 22                             Pork belly with mustard
# 23                                   pork and muchroom
# 24                                      ramen and pork
# 25                                  Sandwich with pork
# 26                      Pork belly with dark soy sauce
# 27                                      Pork and chili
# 28                                                Pork
# 29                                     Pork and garlic
# ..                                                 ...
# 79                          Sandwich with cheese patty
# 80                                   Deep fried cheese
# 81                         Italian lasagna with cheese
# 82                              Sweet tart with cheese
# 83                          Cake that add cheese layer
# 84                              Bread bacon and cheese
# 85                              Deep fried cheese ball
# 86   This Avocado Salad from Delish.com proves avoc...
# 87                               Salad with fried fish
# 88                             Salad with grilled beef
# 89                           Salad with grilled shrimp
# 90                 This salad made from vegetable only
# 91                        Mixed fruit serve like salad
# 92                                     Salad with kiwi
# 93                                 Salad with macaroni
# 94                  Salad with crispy bread and cheese
# 95                           Salad with only vegetable
# 96                           Salad with fresh tomatoes
# 97            Steamed veggie with curry paste enjoy !!
# 98                             Bread mixed with veggie
# 99                       Toast bread with veggie toast
# 100                             Egg noodle with veggie
# 101     Pizza with cream cheese and crunchy vegetables
# 102                          Soup with fresh vegetable
# 103                         Rice with mix of vegetable
# 104              Dark chocolate combine with vegetable
# 105           Stir fried sukiyaki with fresh vegetable
# 106                         Fresh vegetable deep fried
# 107  1 pound extra-lean ground chicken\n\n½ cup Ita...
# 108                                       Vegan burger
#
#                                                  bodys comments  \
# 0                                  Very very delicious      NaN
# 1    \n1. Sauté the scallions and garlic.\n2 Cook t...      NaN
# 2    1. Mix flour, baking powder, salt, and sugar\n...      NaN
# 3                                                  sss      NaN
# 4    1. PREHEAT oven to 350°F. Brown meat in large ...      NaN
# 5    Step 1: Heat the pan on medium fire. Sprinkle ...      NaN
# 6    1. Cook pasta in a large pot of boiling water ...      NaN
# 7    1. Soak the brisket in a bowl of water and set...      NaN
# 8    Lightly grease a 12 hole muffin tin and pre-he...      NaN
# 9    Step 1: Beat 6 egg yolks, and then pour them t...      NaN
# 10   1. Break the egg and put it into a bowl.\n2. A...      NaN
# 11   Whisk chicken broth, oyster sauce, soy sauce, ...      NaN
# 12   Place glutinous rice in a large container and ...      NaN
# 13   Heat the oil in a large pot over medium heat. ...      NaN
# 14   Cut chicken into thin strips and saute in oil ...      NaN
# 15   In a small bowl, mix together mayonnaise, coco...      NaN
# 16   Bring a medium stockpot of lightly salted wate...      NaN
# 17   1. Place the kimchi in a shallow, heavy pot or...      NaN
# 18   1. Cook the macaroni pasta following the packa...      NaN
# 19   1. Combine the spicy Korean ketchup sauce ingr...       []
# 20                                                 NaN      NaN
# 21                                                 NaN      NaN
# 22                                                 NaN      NaN
# 23                                                 NaN      NaN
# 24                                                 NaN      NaN
# 25                                                 NaN      NaN
# 26                                                 NaN      NaN
# 27                                                 NaN       []
# 28                                                 NaN      NaN
# 29                                                 NaN      NaN
# ..                                                 ...      ...
# 79                                                 NaN       []
# 80                                                 NaN       []
# 81                                                 NaN       []
# 82                                                 NaN       []
# 83                                                 NaN       []
# 84                                                 NaN       []
# 85                                             sssssss       []
# 86                                                 NaN       []
# 87                                                 NaN       []
# 88                                                 NaN       []
# 89                                                 NaN       []
# 90                                                 NaN       []
# 91                                                 NaN       []
# 92                                                 NaN       []
# 93                                                 NaN       []
# 94                                                 NaN       []
# 95                                                 NaN       []
# 96                                                 NaN       []
# 97                                                 NaN       []
# 98                                                 NaN       []
# 99                                                 NaN       []
# 100                                                NaN       []
# 101                                                NaN       []
# 102                                                NaN       []
# 103                                                NaN       []
# 104                                                NaN       []
# 105                                                NaN       []
# 106                                                NaN       []
# 107  Step 1\nMix ground chicken, 1/4 cup bread crum...      NaN
# 108                                       Vegan burger      NaN
#
#                     created followers following  \
# 0   2019-07-09 20:20:04.604       NaN       NaN
# 1   2019-07-17 12:35:49.552       NaN       NaN
# 2   2019-07-17 12:48:30.463       NaN       NaN
# 3   2019-07-17 12:52:16.250        []        []
# 4   2019-07-17 12:54:16.960       NaN       NaN
# 5   2019-07-17 12:58:40.278       NaN       NaN
# 6   2019-07-17 13:09:09.700       NaN       NaN
# 7   2019-07-17 13:12:51.557       NaN       NaN
# 8   2019-07-17 16:28:47.544       NaN       NaN
# 9   2019-07-17 16:38:14.035       NaN       NaN
# 10  2019-07-19 10:34:41.638       NaN       NaN
# 11  2019-07-29 14:12:45.366       NaN       NaN
# 12  2019-07-29 14:16:10.214       NaN       NaN
# 13  2019-07-29 14:26:49.205       NaN       NaN
# 14  2019-07-29 14:28:06.779       NaN       NaN
# 15  2019-07-29 14:30:23.620       NaN       NaN
# 16  2019-07-29 14:34:32.097       NaN       NaN
# 17  2019-07-29 16:08:47.395       NaN       NaN
# 18  2019-07-29 16:12:45.204       NaN       NaN
# 19  2019-07-29 16:19:21.589       NaN       NaN
# 20  2019-07-09 20:20:04.604       NaN       NaN
# 21  2019-07-09 20:20:04.604       NaN       NaN
# 22  2019-07-09 20:20:04.604       NaN       NaN
# 23  2019-07-09 20:20:04.604       NaN       NaN
# 24  2019-07-09 20:20:04.604       NaN       NaN
# 25  2019-07-09 20:20:04.604       NaN       NaN
# 26  2019-07-09 20:20:04.604       NaN       NaN
# 27  2019-07-09 20:20:04.604       NaN       NaN
# 28  2019-07-09 20:20:04.604       NaN       NaN
# 29  2019-07-09 20:20:04.604       NaN       NaN
# ..                      ...       ...       ...
# 79  2019-08-21 14:36:31.180       NaN       NaN
# 80  2019-08-21 14:36:31.180       NaN       NaN
# 81  2019-08-21 14:36:31.180       NaN       NaN
# 82  2019-08-21 14:36:31.180       NaN       NaN
# 83  2019-08-21 14:36:31.180       NaN       NaN
# 84  2019-08-21 14:36:31.180       NaN       NaN
# 85  2019-08-21 14:36:31.180       NaN       NaN
# 86  2019-08-21 14:49:33.712       NaN       NaN
# 87  2019-08-21 14:49:33.712       NaN       NaN
# 88  2019-08-21 14:49:33.712       NaN       NaN
# 89  2019-08-21 14:49:33.712       NaN       NaN
# 90  2019-08-21 14:49:33.712       NaN       NaN
# 91  2019-08-21 14:49:33.712       NaN       NaN
# 92  2019-08-21 14:49:33.712       NaN       NaN
# 93  2019-08-21 14:49:33.712       NaN       NaN
# 94  2019-08-21 14:49:33.712       NaN       NaN
# 95  2019-08-21 14:49:33.712       NaN       NaN
# 96  2019-08-21 14:49:33.712       NaN       NaN
# 97  2019-08-21 15:09:00.767       NaN       NaN
# 98  2019-08-21 15:09:00.767       NaN       NaN
# 99  2019-08-21 15:09:00.767       NaN       NaN
# 100 2019-08-21 15:09:00.767       NaN       NaN
# 101 2019-08-21 15:09:00.767       NaN       NaN
# 102 2019-08-21 15:09:00.767       NaN       NaN
# 103 2019-08-21 15:09:00.767       NaN       NaN
# 104 2019-08-21 15:09:00.767       NaN       NaN
# 105 2019-08-21 15:09:00.767       NaN       NaN
# 106 2019-08-21 15:09:00.767       NaN       NaN
# 107 2019-10-16 15:59:33.505       NaN       NaN
# 108 2019-10-16 17:47:04.918       NaN       NaN
#
#                                                  likes  \
# 0                           [5d2f19959b09d20d4cf4320f]
# 1    [5d2f1d399b09d20d4cf43216, 5d2f1d399b09d20d4cf...
# 2                           [5d2f19959b09d20d4cf4320f]
# 3                                                   []
# 4                           [5d2f1d399b09d20d4cf43216]
# 5                                                   []
# 6                                                   []
# 7    [5d2f1d399b09d20d4cf43216, 5d2f1d399b09d20d4cf...
# 8                                                   []
# 9                                                   []
# 10   [5d319a3a3f5b8b0fc4038e03, 5d2f19959b09d20d4cf...
# 11                                                  []
# 12                                                  []
# 13                                                  []
# 14                          [5d2f1d399b09d20d4cf43216]
# 15                                                  []
# 16                          [5d319a3a3f5b8b0fc4038e03]
# 17                          [5d2f1d399b09d20d4cf43216]
# 18                          [5d2f19959b09d20d4cf4320f]
# 19                                                  []
# 20                                                  []
# 21                                                  []
# 22   [5d2f19959b09d20d4cf4320f, 5d2f15848ed63b1dcce...
# 23                                                  []
# 24                                                  []
# 25                                                  []
# 26                                                  []
# 27                          [5d2f1d399b09d20d4cf43216]
# 28                                                  []
# 29                                                  []
# ..                                                 ...
# 79                                                  []
# 80                                                  []
# 81                                                  []
# 82                                                  []
# 83                                                  []
# 84                                                  []
# 85                                                  []
# 86                                                  []
# 87                                                  []
# 88                                                  []
# 89                                                  []
# 90                                                  []
# 91                                                  []
# 92                                                  []
# 93                                                  []
# 94                                                  []
# 95                                                  []
# 96                                                  []
# 97                                                  []
# 98                                                  []
# 99                                                  []
# 100                                                 []
# 101                                                 []
# 102                                                 []
# 103                                                 []
# 104                                                 []
# 105                                                 []
# 106                                                 []
# 107                                                 []
# 108                                                 []
#
#                                                  photo  \
# 0    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 1    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 2    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 3    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 4    {'contentType': 'image/jpeg', 'data': b'\xff\x...
# 5    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 6    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 7    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 8    {'data': b'\xff\xd8\xff\xe1\x13\xd4Exif\x00\x0...
# 9    {'contentType': 'image/jpeg', 'data': b'\xff\x...
# 10   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 11   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 12   {'contentType': 'image/jpeg', 'data': b'\xff\x...
# 13   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 14   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 15   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 16   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 17   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 18   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 19   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 20   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 21   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 22   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 23   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 24   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 25   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 26   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 27   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 28   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 29   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# ..                                                 ...
# 79   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 80   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 81   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 82   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 83   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 84   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 85   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 86   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 87   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 88   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 89   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 90   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 91   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 92   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 93   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 94   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 95   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 96   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 97   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 98   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 99   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 100  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 101  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 102  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 103  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 104  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 105  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 106  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 107  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 108  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
#
#                      postedBy  \
# 0    5d208546d6f6f23ee441c2fd
# 1    5d2f15848ed63b1dcceb7000
# 2    5d2f15848ed63b1dcceb7000
# 3    5d2f19959b09d20d4cf4320f
# 4    5d2f19959b09d20d4cf4320f
# 5    5d2f19959b09d20d4cf4320f
# 6    5d2f1d399b09d20d4cf43216
# 7    5d2f1e299b09d20d4cf43219
# 8    5d2f4b729b09d20d4cf4321c
# 9    5d2f4b729b09d20d4cf4321c
# 10   5d319a3a3f5b8b0fc4038e03
# 11   5d2f15848ed63b1dcceb7000
# 12   5d2f15848ed63b1dcceb7000
# 13   5d2f15848ed63b1dcceb7000
# 14   5d2f15848ed63b1dcceb7000
# 15   5d2f15848ed63b1dcceb7000
# 16   5d2f1d399b09d20d4cf43216
# 17   5d2f1d399b09d20d4cf43216
# 18   5d2f1d399b09d20d4cf43216
# 19   5d2f19959b09d20d4cf4320f
# 20   5d208546d6f6f23ee441c2fd
# 21   5d208546d6f6f23ee441c2fd
# 22   5d208546d6f6f23ee441c2fd
# 23   5d208546d6f6f23ee441c2fd
# 24   5d208546d6f6f23ee441c2fd
# 25   5d208546d6f6f23ee441c2fd
# 26   5d208546d6f6f23ee441c2fd
# 27   5d208546d6f6f23ee441c2fd
# 28   5d208546d6f6f23ee441c2fd
# 29   5d208546d6f6f23ee441c2fd
# ..                        ...
# 79   5d305984d6ef2d0ecc15d2be
# 80   5d305984d6ef2d0ecc15d2be
# 81   5d305984d6ef2d0ecc15d2be
# 82   5d305984d6ef2d0ecc15d2be
# 83   5d305984d6ef2d0ecc15d2be
# 84   5d305984d6ef2d0ecc15d2be
# 85   5d305984d6ef2d0ecc15d2be
# 86   5d46f4810fe7493978544fff
# 87   5d46f4810fe7493978544fff
# 88   5d46f4810fe7493978544fff
# 89   5d46f4810fe7493978544fff
# 90   5d46f4810fe7493978544fff
# 91   5d46f4810fe7493978544fff
# 92   5d46f4810fe7493978544fff
# 93   5d46f4810fe7493978544fff
# 94   5d46f4810fe7493978544fff
# 95   5d46f4810fe7493978544fff
# 96   5d46f4810fe7493978544fff
# 97   5d32e1e282cebe4330489703
# 98   5d32e1e282cebe4330489703
# 99   5d32e1e282cebe4330489703
# 100  5d32e1e282cebe4330489703
# 101  5d32e1e282cebe4330489703
# 102  5d32e1e282cebe4330489703
# 103  5d32e1e282cebe4330489703
# 104  5d32e1e282cebe4330489703
# 105  5d32e1e282cebe4330489703
# 106  5d32e1e282cebe4330489703
# 107  5d2f15848ed63b1dcceb7000
# 108  5d2f15848ed63b1dcceb7000
#
#                                                title     type  \
# 0                                  Strawberry Yogurt    sweet
# 1                                Pad Thai (Udontani)   noodle
# 2                                            Pancake    sweet
# 3                                      Ramen noodles      egg
# 4                                    Lasagna (Italy)     pork
# 5                                       Salmon steak    steak
# 6                                        Pasta pesto   noodle
# 7                           DONGCHIMI MUL NAENGMYEON   noodle
# 8                                    Pastéis de Nata    sweet
# 9                                    Sweet egg floss    sweet
# 10                                        Omelet egg      egg
# 11         Spicy Thai Basil Chicken (Pad Krapow Gai)  chicken
# 12              Refined Sugar Free-Mango Sticky Rice    sweet
# 13                        The Best Thai Coconut Soup     soup
# 14                 Tom Ka Gai (Coconut Chicken Soup)  chicken
# 15                              Thai Chicken Burgers  chicken
# 16         Thai Basil Rolls with Hoisin-Peanut Sauce     pork
# 17                             Kimchi stew with tuna     soup
# 18                             KOREAN MACARONI SALAD    salad
# 19             KOREAN TOFU WITH SPICY KOREAN KETCHUP     soup
# 20             Deep fried pork belly with fish sauce     pork
# 21   Stir fried pork belly with chili and holy basil     pork
# 22       Pork belly grilled with white mustard sauce     pork
# 23                     Muchroom stir fried with pork     pork
# 24                    Ramen noodle with special pork     pork
# 25                               Sandwich fried pork     pork
# 26        Slow cooked pork belly with dark soy sauce     pork
# 27                          Nam prik with pork chops     pork
# 28                                         Pork ball     pork
# 29            Deep fried pork with garlic and pepper     pork
# ..                                               ...      ...
# 79                                   Sandwich cheese   cheese
# 80                                      Fried cheese   cheese
# 81                                    Lasagna cheese   cheese
# 82                                       Cheese tart   cheese
# 83                                       Cheese cake   cheese
# 84                     Bacon bread with cheese sauce   cheese
# 85                                       Cheese ball   cheese
# 86                                     Avocado salad    salad
# 87                                        Fish salad    salad
# 88                                        Beef salad    salad
# 89                                      Shrimp salad    salad
# 90                               Cowboy caviar salad    salad
# 91                                       Fruit salad    salad
# 92                                        Kiwi salad    salad
# 93                                    Macaroni salad    salad
# 94                                      Carsar salad    salad
# 95                                      Veggie salad    salad
# 96                                    Tomatoes salad    salad
# 97                   Steamed veggie with curry paste   veggie
# 98                                      Veggie bread   veggie
# 99                                      Veggie toast   veggie
# 100                                    Veggie noodle   veggie
# 101                                     Veggie pizza   veggie
# 102                                      Veggie soup   veggie
# 103                                 Veggie rice bowl   veggie
# 104                       Dark chocolate veggie bite   veggie
# 105                       Sukiyaki with fresh veggie   veggie
# 106                          Veggie stick deep fried   veggie
# 107                                  Chicken burgers  burgers
# 108                                     Vegan burger  burgers
#
#                     updated
# 0   2019-10-16 19:56:06.786
# 1   2019-07-17 12:46:15.086
# 2                       NaT
# 3   2019-10-16 18:46:11.369
# 4   2019-07-17 12:59:23.448
# 5                       NaT
# 6   2019-10-15 19:41:27.957
# 7                       NaT
# 8                       NaT
# 9   2019-07-17 16:39:24.458
# 10  2019-07-20 17:07:48.171
# 11                      NaT
# 12  2019-07-29 14:16:19.992
# 13                      NaT
# 14                      NaT
# 15  2019-10-16 15:47:15.854
# 16  2019-08-06 14:28:49.188
# 17                      NaT
# 18  2019-08-06 14:26:22.358
# 19  2019-10-15 16:43:53.432
# 20  2019-07-10 16:20:07.442
# 21  2019-07-10 16:20:07.442
# 22  2019-07-10 16:20:07.442
# 23  2019-07-10 16:20:07.442
# 24  2019-07-10 16:20:07.442
# 25  2019-07-10 16:20:07.442
# 26  2019-07-10 16:20:07.442
# 27  2019-08-21 13:29:27.352
# 28  2019-07-10 16:20:07.442
# 29  2019-07-10 16:20:07.442
# ..                      ...
# 79                      NaT
# 80                      NaT
# 81                      NaT
# 82                      NaT
# 83                      NaT
# 84                      NaT
# 85  2019-10-23 22:27:07.950
# 86                      NaT
# 87                      NaT
# 88                      NaT
# 89                      NaT
# 90                      NaT
# 91                      NaT
# 92                      NaT
# 93                      NaT
# 94                      NaT
# 95                      NaT
# 96                      NaT
# 97                      NaT
# 98                      NaT
# 99                      NaT
# 100                     NaT
# 101                     NaT
# 102                     NaT
# 103                     NaT
# 104                     NaT
# 105                     NaT
# 106                     NaT
# 107                     NaT
# 108                     NaT
#
# [109 rows x 15 columns]

# %%
data.columns[data.isna().any()].tolist()
# Out:
# []

# %%
data2['likes']
# Out:
# 0                             [5d2f19959b09d20d4cf4320f]
# 1      [5d2f1d399b09d20d4cf43216, 5d2f1d399b09d20d4cf...
# 2                             [5d2f19959b09d20d4cf4320f]
# 3                                                     []
# 4                             [5d2f1d399b09d20d4cf43216]
# 5                                                     []
# 6                                                     []
# 7      [5d2f1d399b09d20d4cf43216, 5d2f1d399b09d20d4cf...
# 8                                                     []
# 9                                                     []
# 10     [5d319a3a3f5b8b0fc4038e03, 5d2f19959b09d20d4cf...
# 11                                                    []
# 12                                                    []
# 13                                                    []
# 14                            [5d2f1d399b09d20d4cf43216]
# 15                                                    []
# 16                            [5d319a3a3f5b8b0fc4038e03]
# 17                            [5d2f1d399b09d20d4cf43216]
# 18                            [5d2f19959b09d20d4cf4320f]
# 19                                                    []
# 20                                                    []
# 21                                                    []
# 22     [5d2f19959b09d20d4cf4320f, 5d2f15848ed63b1dcce...
# 23                                                    []
# 24                                                    []
# 25                                                    []
# 26                                                    []
# 27                            [5d2f1d399b09d20d4cf43216]
# 28                                                    []
# 29                                                    []
#                              ...
# 79                                                    []
# 80                                                    []
# 81                                                    []
# 82                                                    []
# 83                                                    []
# 84                                                    []
# 85                                                    []
# 86                                                    []
# 87                                                    []
# 88                                                    []
# 89                                                    []
# 90                                                    []
# 91                                                    []
# 92                                                    []
# 93                                                    []
# 94                                                    []
# 95                                                    []
# 96                                                    []
# 97                                                    []
# 98                                                    []
# 99                                                    []
# 100                                                   []
# 101                                                   []
# 102                                                   []
# 103                                                   []
# 104                                                   []
# 105                                                   []
# 106                                                   []
# 107                                                   []
# 108                                                   []
# Name: likes, Length: 109, dtype: object

# %%
data2['likes'].count()
# Out:
# 109

# %%
sum(map(len, data2['likes'].values()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-284-9fee32ba9455> in <module>
# ----> 1 sum(map(len, data2['likes'].values()))
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
type(len(data2['likes'][11]))
# Out:
# int

# %%
countlist= []

# %%
for i in range(0,109):
    countlist.append(len(data2['likes'][i]))

# %%
data2['countlist'] = countlist

# %%
data2
# Out:
#      __v                       _id advertisement  \
# 0      0  5d24f6f4884f593e74d4b399           NaN
# 1      0  5d2f16258ed63b1dcceb7002           NaN
# 2      0  5d2f191e9b09d20d4cf4320e           NaN
# 3      1  5d2f1a009b09d20d4cf43211            {}
# 4      0  5d2f1a789b09d20d4cf43213           NaN
# 5      0  5d2f1b809b09d20d4cf43215           NaN
# 6      0  5d2f1df59b09d20d4cf43218           NaN
# 7      0  5d2f1ed39b09d20d4cf4321b           NaN
# 8      0  5d2f4cbf9b09d20d4cf4321e           NaN
# 9      0  5d2f4ef69b09d20d4cf43220           NaN
# 10     0  5d319cc13f5b8b0fc4038e07           NaN
# 11     0  5d3efedd20f12936c0b6b449           NaN
# 12     0  5d3effaa20f12936c0b6b44b           NaN
# 13     0  5d3f022920f12936c0b6b44d           NaN
# 14     0  5d3f027620f12936c0b6b44f           NaN
# 15     0  5d3f02ff20f12936c0b6b451           NaN
# 16     0  5d3f03f820f12936c0b6b453           NaN
# 17     0  5d3f1a0f20f12936c0b6b457           NaN
# 18     0  5d3f1afd20f12936c0b6b459           NaN
# 19     0  5d3f1c8920f12936c0b6b45b           NaN
# 20     0  5d5d2d641c9d440000110093           NaN
# 21     0  5d5d2e871c9d440000110094           NaN
# 22     0  5d5d2edc1c9d440000110095           NaN
# 23     0  5d5d3bc81c9d44000011009e           NaN
# 24     0  5d5d3c411c9d44000011009f           NaN
# 25     0  5d5d3c781c9d4400001100a0           NaN
# 26     0  5d5d3cf71c9d4400001100a1           NaN
# 27     0  5d5d3d361c9d4400001100a2           NaN
# 28     0  5d5d3da71c9d4400001100a3           NaN
# 29     0  5d5d3dde1c9d4400001100a5           NaN
# ..   ...                       ...           ...
# 79     0  5d5d57991c9d4400001100d8           NaN
# 80     0  5d5d57cb1c9d4400001100d9           NaN
# 81     0  5d5d57e91c9d4400001100da           NaN
# 82     0  5d5d581d1c9d4400001100db           NaN
# 83     0  5d5d583a1c9d4400001100dc           NaN
# 84     0  5d5d58fa1c9d4400001100dd           NaN
# 85     0  5d5d59311c9d4400001100de           NaN
# 86     0  5d5d59fdf670cf3c883ad0f9           NaN
# 87     0  5d5d5a411c9d4400001100df           NaN
# 88     0  5d5d5a811c9d4400001100e0           NaN
# 89     0  5d5d5aa61c9d4400001100e1           NaN
# 90     0  5d5d5ac91c9d4400001100e3           NaN
# 91     0  5d5d5b521c9d4400001100e4           NaN
# 92     0  5d5d5bbf1c9d4400001100e5           NaN
# 93     0  5d5d5cbf1c9d4400001100e6           NaN
# 94     0  5d5d5cdc1c9d4400001100e7           NaN
# 95     0  5d5d5d241c9d4400001100e8           NaN
# 96     0  5d5d5d421c9d4400001100e9           NaN
# 97     0  5d5d5e8cf670cf3c883ad0fa           NaN
# 98     0  5d5d5eea1c9d4400001100ea           NaN
# 99     0  5d5d5f0a1c9d4400001100eb           NaN
# 100    0  5d5d5f491c9d4400001100ec           NaN
# 101    0  5d5d5f931c9d4400001100ed           NaN
# 102    0  5d5d5fe21c9d4400001100ee           NaN
# 103    0  5d5d60201c9d4400001100ef           NaN
# 104    0  5d5d605c1c9d4400001100f0           NaN
# 105    0  5d5d60c51c9d4400001100f1           NaN
# 106    0  5d5d61431c9d4400001100f2           NaN
# 107    0  5da73e651312a31c5847b37a           NaN
# 108    0  5da757987a7f2510cc57780d           NaN
#
#                                                   body  \
# 0                                 Milk with strawberry
# 1    4 ounces dried Thai rice noodles\n1 ounce tama...
# 2    whisk, two mixing bowls, pan or griddle, veget...
# 3    2½ cups (590 milliliters) water\n1 packet of r...
# 4    2 x 28 oz. cans tomatoes - crushed or whole is...
# 5    Easier and faster it can not be done. A salmon...
# 6    1/2 cup chopped onion2 1/2 tablespoons pesto2 ...
# 7    200 g / 7 ounce dried naengmyeon noodles (Kore...
# 8    2 cups minus 2 tablespoons all-purpose flour, ...
# 9     1 1/2 cups of sugar\n 6 egg yolks\n 2 drops o...
# 10                      \nEgg, Olive oil, Fish sauce\n
# 11   1/3 cup chicken broth1 tablespoon oyster sauce...
# 12   1/2 cup Thai glutinous rice1 1/3 cups coconut ...
# 13   1 tablespoon vegetable oil2 tablespoons grated...
# 14   3/4 pound boneless, skinless chicken meat3 tab...
# 15   1 cup mayonnaise1/4 cup flaked coconut, finely...
# 16   1/2 pound medium shrimp1/2 pound pork loin1 (8...
# 17   1 or 2 cans of tuna\n1 pound fermented kimchi,...
# 18   200g / 7 ounces elbow macaroni \n50g / 1.7 oun...
# 19   3 Tbsp ketchup (also known as tomato sauce in ...
# 20                           Pork belly and fish sauce
# 21                Pork belly with chili and holy basil
# 22                             Pork belly with mustard
# 23                                   pork and muchroom
# 24                                      ramen and pork
# 25                                  Sandwich with pork
# 26                      Pork belly with dark soy sauce
# 27                                      Pork and chili
# 28                                                Pork
# 29                                     Pork and garlic
# ..                                                 ...
# 79                          Sandwich with cheese patty
# 80                                   Deep fried cheese
# 81                         Italian lasagna with cheese
# 82                              Sweet tart with cheese
# 83                          Cake that add cheese layer
# 84                              Bread bacon and cheese
# 85                              Deep fried cheese ball
# 86   This Avocado Salad from Delish.com proves avoc...
# 87                               Salad with fried fish
# 88                             Salad with grilled beef
# 89                           Salad with grilled shrimp
# 90                 This salad made from vegetable only
# 91                        Mixed fruit serve like salad
# 92                                     Salad with kiwi
# 93                                 Salad with macaroni
# 94                  Salad with crispy bread and cheese
# 95                           Salad with only vegetable
# 96                           Salad with fresh tomatoes
# 97            Steamed veggie with curry paste enjoy !!
# 98                             Bread mixed with veggie
# 99                       Toast bread with veggie toast
# 100                             Egg noodle with veggie
# 101     Pizza with cream cheese and crunchy vegetables
# 102                          Soup with fresh vegetable
# 103                         Rice with mix of vegetable
# 104              Dark chocolate combine with vegetable
# 105           Stir fried sukiyaki with fresh vegetable
# 106                         Fresh vegetable deep fried
# 107  1 pound extra-lean ground chicken\n\n½ cup Ita...
# 108                                       Vegan burger
#
#                                                  bodys comments  \
# 0                                  Very very delicious      NaN
# 1    \n1. Sauté the scallions and garlic.\n2 Cook t...      NaN
# 2    1. Mix flour, baking powder, salt, and sugar\n...      NaN
# 3                                                  sss      NaN
# 4    1. PREHEAT oven to 350°F. Brown meat in large ...      NaN
# 5    Step 1: Heat the pan on medium fire. Sprinkle ...      NaN
# 6    1. Cook pasta in a large pot of boiling water ...      NaN
# 7    1. Soak the brisket in a bowl of water and set...      NaN
# 8    Lightly grease a 12 hole muffin tin and pre-he...      NaN
# 9    Step 1: Beat 6 egg yolks, and then pour them t...      NaN
# 10   1. Break the egg and put it into a bowl.\n2. A...      NaN
# 11   Whisk chicken broth, oyster sauce, soy sauce, ...      NaN
# 12   Place glutinous rice in a large container and ...      NaN
# 13   Heat the oil in a large pot over medium heat. ...      NaN
# 14   Cut chicken into thin strips and saute in oil ...      NaN
# 15   In a small bowl, mix together mayonnaise, coco...      NaN
# 16   Bring a medium stockpot of lightly salted wate...      NaN
# 17   1. Place the kimchi in a shallow, heavy pot or...      NaN
# 18   1. Cook the macaroni pasta following the packa...      NaN
# 19   1. Combine the spicy Korean ketchup sauce ingr...       []
# 20                                                 NaN      NaN
# 21                                                 NaN      NaN
# 22                                                 NaN      NaN
# 23                                                 NaN      NaN
# 24                                                 NaN      NaN
# 25                                                 NaN      NaN
# 26                                                 NaN      NaN
# 27                                                 NaN       []
# 28                                                 NaN      NaN
# 29                                                 NaN      NaN
# ..                                                 ...      ...
# 79                                                 NaN       []
# 80                                                 NaN       []
# 81                                                 NaN       []
# 82                                                 NaN       []
# 83                                                 NaN       []
# 84                                                 NaN       []
# 85                                             sssssss       []
# 86                                                 NaN       []
# 87                                                 NaN       []
# 88                                                 NaN       []
# 89                                                 NaN       []
# 90                                                 NaN       []
# 91                                                 NaN       []
# 92                                                 NaN       []
# 93                                                 NaN       []
# 94                                                 NaN       []
# 95                                                 NaN       []
# 96                                                 NaN       []
# 97                                                 NaN       []
# 98                                                 NaN       []
# 99                                                 NaN       []
# 100                                                NaN       []
# 101                                                NaN       []
# 102                                                NaN       []
# 103                                                NaN       []
# 104                                                NaN       []
# 105                                                NaN       []
# 106                                                NaN       []
# 107  Step 1\nMix ground chicken, 1/4 cup bread crum...      NaN
# 108                                       Vegan burger      NaN
#
#                     created followers following  \
# 0   2019-07-09 20:20:04.604       NaN       NaN
# 1   2019-07-17 12:35:49.552       NaN       NaN
# 2   2019-07-17 12:48:30.463       NaN       NaN
# 3   2019-07-17 12:52:16.250        []        []
# 4   2019-07-17 12:54:16.960       NaN       NaN
# 5   2019-07-17 12:58:40.278       NaN       NaN
# 6   2019-07-17 13:09:09.700       NaN       NaN
# 7   2019-07-17 13:12:51.557       NaN       NaN
# 8   2019-07-17 16:28:47.544       NaN       NaN
# 9   2019-07-17 16:38:14.035       NaN       NaN
# 10  2019-07-19 10:34:41.638       NaN       NaN
# 11  2019-07-29 14:12:45.366       NaN       NaN
# 12  2019-07-29 14:16:10.214       NaN       NaN
# 13  2019-07-29 14:26:49.205       NaN       NaN
# 14  2019-07-29 14:28:06.779       NaN       NaN
# 15  2019-07-29 14:30:23.620       NaN       NaN
# 16  2019-07-29 14:34:32.097       NaN       NaN
# 17  2019-07-29 16:08:47.395       NaN       NaN
# 18  2019-07-29 16:12:45.204       NaN       NaN
# 19  2019-07-29 16:19:21.589       NaN       NaN
# 20  2019-07-09 20:20:04.604       NaN       NaN
# 21  2019-07-09 20:20:04.604       NaN       NaN
# 22  2019-07-09 20:20:04.604       NaN       NaN
# 23  2019-07-09 20:20:04.604       NaN       NaN
# 24  2019-07-09 20:20:04.604       NaN       NaN
# 25  2019-07-09 20:20:04.604       NaN       NaN
# 26  2019-07-09 20:20:04.604       NaN       NaN
# 27  2019-07-09 20:20:04.604       NaN       NaN
# 28  2019-07-09 20:20:04.604       NaN       NaN
# 29  2019-07-09 20:20:04.604       NaN       NaN
# ..                      ...       ...       ...
# 79  2019-08-21 14:36:31.180       NaN       NaN
# 80  2019-08-21 14:36:31.180       NaN       NaN
# 81  2019-08-21 14:36:31.180       NaN       NaN
# 82  2019-08-21 14:36:31.180       NaN       NaN
# 83  2019-08-21 14:36:31.180       NaN       NaN
# 84  2019-08-21 14:36:31.180       NaN       NaN
# 85  2019-08-21 14:36:31.180       NaN       NaN
# 86  2019-08-21 14:49:33.712       NaN       NaN
# 87  2019-08-21 14:49:33.712       NaN       NaN
# 88  2019-08-21 14:49:33.712       NaN       NaN
# 89  2019-08-21 14:49:33.712       NaN       NaN
# 90  2019-08-21 14:49:33.712       NaN       NaN
# 91  2019-08-21 14:49:33.712       NaN       NaN
# 92  2019-08-21 14:49:33.712       NaN       NaN
# 93  2019-08-21 14:49:33.712       NaN       NaN
# 94  2019-08-21 14:49:33.712       NaN       NaN
# 95  2019-08-21 14:49:33.712       NaN       NaN
# 96  2019-08-21 14:49:33.712       NaN       NaN
# 97  2019-08-21 15:09:00.767       NaN       NaN
# 98  2019-08-21 15:09:00.767       NaN       NaN
# 99  2019-08-21 15:09:00.767       NaN       NaN
# 100 2019-08-21 15:09:00.767       NaN       NaN
# 101 2019-08-21 15:09:00.767       NaN       NaN
# 102 2019-08-21 15:09:00.767       NaN       NaN
# 103 2019-08-21 15:09:00.767       NaN       NaN
# 104 2019-08-21 15:09:00.767       NaN       NaN
# 105 2019-08-21 15:09:00.767       NaN       NaN
# 106 2019-08-21 15:09:00.767       NaN       NaN
# 107 2019-10-16 15:59:33.505       NaN       NaN
# 108 2019-10-16 17:47:04.918       NaN       NaN
#
#                                                  likes  \
# 0                           [5d2f19959b09d20d4cf4320f]
# 1    [5d2f1d399b09d20d4cf43216, 5d2f1d399b09d20d4cf...
# 2                           [5d2f19959b09d20d4cf4320f]
# 3                                                   []
# 4                           [5d2f1d399b09d20d4cf43216]
# 5                                                   []
# 6                                                   []
# 7    [5d2f1d399b09d20d4cf43216, 5d2f1d399b09d20d4cf...
# 8                                                   []
# 9                                                   []
# 10   [5d319a3a3f5b8b0fc4038e03, 5d2f19959b09d20d4cf...
# 11                                                  []
# 12                                                  []
# 13                                                  []
# 14                          [5d2f1d399b09d20d4cf43216]
# 15                                                  []
# 16                          [5d319a3a3f5b8b0fc4038e03]
# 17                          [5d2f1d399b09d20d4cf43216]
# 18                          [5d2f19959b09d20d4cf4320f]
# 19                                                  []
# 20                                                  []
# 21                                                  []
# 22   [5d2f19959b09d20d4cf4320f, 5d2f15848ed63b1dcce...
# 23                                                  []
# 24                                                  []
# 25                                                  []
# 26                                                  []
# 27                          [5d2f1d399b09d20d4cf43216]
# 28                                                  []
# 29                                                  []
# ..                                                 ...
# 79                                                  []
# 80                                                  []
# 81                                                  []
# 82                                                  []
# 83                                                  []
# 84                                                  []
# 85                                                  []
# 86                                                  []
# 87                                                  []
# 88                                                  []
# 89                                                  []
# 90                                                  []
# 91                                                  []
# 92                                                  []
# 93                                                  []
# 94                                                  []
# 95                                                  []
# 96                                                  []
# 97                                                  []
# 98                                                  []
# 99                                                  []
# 100                                                 []
# 101                                                 []
# 102                                                 []
# 103                                                 []
# 104                                                 []
# 105                                                 []
# 106                                                 []
# 107                                                 []
# 108                                                 []
#
#                                                  photo  \
# 0    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 1    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 2    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 3    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 4    {'contentType': 'image/jpeg', 'data': b'\xff\x...
# 5    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 6    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 7    {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 8    {'data': b'\xff\xd8\xff\xe1\x13\xd4Exif\x00\x0...
# 9    {'contentType': 'image/jpeg', 'data': b'\xff\x...
# 10   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 11   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 12   {'contentType': 'image/jpeg', 'data': b'\xff\x...
# 13   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 14   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 15   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 16   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 17   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 18   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 19   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 20   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 21   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 22   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 23   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 24   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 25   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 26   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 27   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 28   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 29   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# ..                                                 ...
# 79   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 80   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 81   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 82   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 83   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 84   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 85   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 86   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 87   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 88   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 89   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 90   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 91   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 92   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 93   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 94   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 95   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 96   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 97   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 98   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 99   {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 100  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 101  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 102  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 103  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 104  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 105  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 106  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 107  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
# 108  {'data': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x0...
#
#                      postedBy  \
# 0    5d208546d6f6f23ee441c2fd
# 1    5d2f15848ed63b1dcceb7000
# 2    5d2f15848ed63b1dcceb7000
# 3    5d2f19959b09d20d4cf4320f
# 4    5d2f19959b09d20d4cf4320f
# 5    5d2f19959b09d20d4cf4320f
# 6    5d2f1d399b09d20d4cf43216
# 7    5d2f1e299b09d20d4cf43219
# 8    5d2f4b729b09d20d4cf4321c
# 9    5d2f4b729b09d20d4cf4321c
# 10   5d319a3a3f5b8b0fc4038e03
# 11   5d2f15848ed63b1dcceb7000
# 12   5d2f15848ed63b1dcceb7000
# 13   5d2f15848ed63b1dcceb7000
# 14   5d2f15848ed63b1dcceb7000
# 15   5d2f15848ed63b1dcceb7000
# 16   5d2f1d399b09d20d4cf43216
# 17   5d2f1d399b09d20d4cf43216
# 18   5d2f1d399b09d20d4cf43216
# 19   5d2f19959b09d20d4cf4320f
# 20   5d208546d6f6f23ee441c2fd
# 21   5d208546d6f6f23ee441c2fd
# 22   5d208546d6f6f23ee441c2fd
# 23   5d208546d6f6f23ee441c2fd
# 24   5d208546d6f6f23ee441c2fd
# 25   5d208546d6f6f23ee441c2fd
# 26   5d208546d6f6f23ee441c2fd
# 27   5d208546d6f6f23ee441c2fd
# 28   5d208546d6f6f23ee441c2fd
# 29   5d208546d6f6f23ee441c2fd
# ..                        ...
# 79   5d305984d6ef2d0ecc15d2be
# 80   5d305984d6ef2d0ecc15d2be
# 81   5d305984d6ef2d0ecc15d2be
# 82   5d305984d6ef2d0ecc15d2be
# 83   5d305984d6ef2d0ecc15d2be
# 84   5d305984d6ef2d0ecc15d2be
# 85   5d305984d6ef2d0ecc15d2be
# 86   5d46f4810fe7493978544fff
# 87   5d46f4810fe7493978544fff
# 88   5d46f4810fe7493978544fff
# 89   5d46f4810fe7493978544fff
# 90   5d46f4810fe7493978544fff
# 91   5d46f4810fe7493978544fff
# 92   5d46f4810fe7493978544fff
# 93   5d46f4810fe7493978544fff
# 94   5d46f4810fe7493978544fff
# 95   5d46f4810fe7493978544fff
# 96   5d46f4810fe7493978544fff
# 97   5d32e1e282cebe4330489703
# 98   5d32e1e282cebe4330489703
# 99   5d32e1e282cebe4330489703
# 100  5d32e1e282cebe4330489703
# 101  5d32e1e282cebe4330489703
# 102  5d32e1e282cebe4330489703
# 103  5d32e1e282cebe4330489703
# 104  5d32e1e282cebe4330489703
# 105  5d32e1e282cebe4330489703
# 106  5d32e1e282cebe4330489703
# 107  5d2f15848ed63b1dcceb7000
# 108  5d2f15848ed63b1dcceb7000
#
#                                                title     type  \
# 0                                  Strawberry Yogurt    sweet
# 1                                Pad Thai (Udontani)   noodle
# 2                                            Pancake    sweet
# 3                                      Ramen noodles      egg
# 4                                    Lasagna (Italy)     pork
# 5                                       Salmon steak    steak
# 6                                        Pasta pesto   noodle
# 7                           DONGCHIMI MUL NAENGMYEON   noodle
# 8                                    Pastéis de Nata    sweet
# 9                                    Sweet egg floss    sweet
# 10                                        Omelet egg      egg
# 11         Spicy Thai Basil Chicken (Pad Krapow Gai)  chicken
# 12              Refined Sugar Free-Mango Sticky Rice    sweet
# 13                        The Best Thai Coconut Soup     soup
# 14                 Tom Ka Gai (Coconut Chicken Soup)  chicken
# 15                              Thai Chicken Burgers  chicken
# 16         Thai Basil Rolls with Hoisin-Peanut Sauce     pork
# 17                             Kimchi stew with tuna     soup
# 18                             KOREAN MACARONI SALAD    salad
# 19             KOREAN TOFU WITH SPICY KOREAN KETCHUP     soup
# 20             Deep fried pork belly with fish sauce     pork
# 21   Stir fried pork belly with chili and holy basil     pork
# 22       Pork belly grilled with white mustard sauce     pork
# 23                     Muchroom stir fried with pork     pork
# 24                    Ramen noodle with special pork     pork
# 25                               Sandwich fried pork     pork
# 26        Slow cooked pork belly with dark soy sauce     pork
# 27                          Nam prik with pork chops     pork
# 28                                         Pork ball     pork
# 29            Deep fried pork with garlic and pepper     pork
# ..                                               ...      ...
# 79                                   Sandwich cheese   cheese
# 80                                      Fried cheese   cheese
# 81                                    Lasagna cheese   cheese
# 82                                       Cheese tart   cheese
# 83                                       Cheese cake   cheese
# 84                     Bacon bread with cheese sauce   cheese
# 85                                       Cheese ball   cheese
# 86                                     Avocado salad    salad
# 87                                        Fish salad    salad
# 88                                        Beef salad    salad
# 89                                      Shrimp salad    salad
# 90                               Cowboy caviar salad    salad
# 91                                       Fruit salad    salad
# 92                                        Kiwi salad    salad
# 93                                    Macaroni salad    salad
# 94                                      Carsar salad    salad
# 95                                      Veggie salad    salad
# 96                                    Tomatoes salad    salad
# 97                   Steamed veggie with curry paste   veggie
# 98                                      Veggie bread   veggie
# 99                                      Veggie toast   veggie
# 100                                    Veggie noodle   veggie
# 101                                     Veggie pizza   veggie
# 102                                      Veggie soup   veggie
# 103                                 Veggie rice bowl   veggie
# 104                       Dark chocolate veggie bite   veggie
# 105                       Sukiyaki with fresh veggie   veggie
# 106                          Veggie stick deep fried   veggie
# 107                                  Chicken burgers  burgers
# 108                                     Vegan burger  burgers
#
#                     updated  countlist
# 0   2019-10-16 19:56:06.786          1
# 1   2019-07-17 12:46:15.086          2
# 2                       NaT          1
# 3   2019-10-16 18:46:11.369          0
# 4   2019-07-17 12:59:23.448          1
# 5                       NaT          0
# 6   2019-10-15 19:41:27.957          0
# 7                       NaT          2
# 8                       NaT          0
# 9   2019-07-17 16:39:24.458          0
# 10  2019-07-20 17:07:48.171          2
# 11                      NaT          0
# 12  2019-07-29 14:16:19.992          0
# 13                      NaT          0
# 14                      NaT          1
# 15  2019-10-16 15:47:15.854          0
# 16  2019-08-06 14:28:49.188          1
# 17                      NaT          1
# 18  2019-08-06 14:26:22.358          1
# 19  2019-10-15 16:43:53.432          0
# 20  2019-07-10 16:20:07.442          0
# 21  2019-07-10 16:20:07.442          0
# 22  2019-07-10 16:20:07.442          3
# 23  2019-07-10 16:20:07.442          0
# 24  2019-07-10 16:20:07.442          0
# 25  2019-07-10 16:20:07.442          0
# 26  2019-07-10 16:20:07.442          0
# 27  2019-08-21 13:29:27.352          1
# 28  2019-07-10 16:20:07.442          0
# 29  2019-07-10 16:20:07.442          0
# ..                      ...        ...
# 79                      NaT          0
# 80                      NaT          0
# 81                      NaT          0
# 82                      NaT          0
# 83                      NaT          0
# 84                      NaT          0
# 85  2019-10-23 22:27:07.950          0
# 86                      NaT          0
# 87                      NaT          0
# 88                      NaT          0
# 89                      NaT          0
# 90                      NaT          0
# 91                      NaT          0
# 92                      NaT          0
# 93                      NaT          0
# 94                      NaT          0
# 95                      NaT          0
# 96                      NaT          0
# 97                      NaT          0
# 98                      NaT          0
# 99                      NaT          0
# 100                     NaT          0
# 101                     NaT          0
# 102                     NaT          0
# 103                     NaT          0
# 104                     NaT          0
# 105                     NaT          0
# 106                     NaT          0
# 107                     NaT          0
# 108                     NaT          0
#
# [109 rows x 16 columns]

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
example_sent = data2['body'][1]
example_sent
# Out:
# '4 ounces dried Thai rice noodles\n1 ounce tamarind paste\n2 tablespoons fish sauce\n2 tablespoons sugar\n1 tablespoon rice wine vinegar\n6 ounces smoked tofu\n1 to 2 tablespoons peanut oil\n1 cup scallions\n2 teaspoons garlic\n2 eggs, beaten\n2 teaspoons cabbage\n1 tablespoon dried shrimp\n3 ounces bean sprouts, divided\n1/2 cup shelled peanuts, divided\nFreshly ground dried red chili peppers, to taste\n1 lime, cut into wedges'

# %%
example_sent2 = example_sent.lower()

# %%
stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(example_sent2) 
  
filtered_sentence = [w for w in word_tokens if not w in stop_words]

# %%
filtered_sentence = [] 
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w)

# %%
print(filtered_sentence)
# Out:
# ['4', 'ounces', 'dried', 'thai', 'rice', 'noodles', '1', 'ounce', 'tamarind', 'paste', '2', 'tablespoons', 'fish', 'sauce', '2', 'tablespoons', 'sugar', '1', 'tablespoon', 'rice', 'wine', 'vinegar', '6', 'ounces', 'smoked', 'tofu', '1', '2', 'tablespoons', 'peanut', 'oil', '1', 'cup', 'scallions', '2', 'teaspoons', 'garlic', '2', 'eggs', ',', 'beaten', '2', 'teaspoons', 'cabbage', '1', 'tablespoon', 'dried', 'shrimp', '3', 'ounces', 'bean', 'sprouts', ',', 'divided', '1/2', 'cup', 'shelled', 'peanuts', ',', 'divided', 'freshly', 'ground', 'dried', 'red', 'chili', 'peppers', ',', 'taste', '1', 'lime', ',', 'cut', 'wedges']

# %%
stop_food = ['(',')','[',']',',','/','1/2','1','2','3','4','5','6','7','8','9','.','bowl','bowls','mix','mixed','divided','divide','freshly','ground',
            'spoon','spoons','tablespoon','tablespoons','cup','teaspoon','teaspoons','dried','taste','beaten','or','ladle',
            'measuring','spatula','griddle','pan','one','two','three','four','six','seven','eight','nine','ten','mixing','large',
            'to','into','cut']

# %%
filtered_sentence2 = [] 
for r in word_tokens: 
    if r not in stop_food: 
        filtered_sentence2.append(r)

# %%
print(filtered_sentence2)
# Out:
# ['ounces', 'thai', 'rice', 'noodles', 'ounce', 'tamarind', 'paste', 'fish', 'sauce', 'sugar', 'rice', 'wine', 'vinegar', 'ounces', 'smoked', 'tofu', 'peanut', 'oil', 'scallions', 'garlic', 'eggs', 'cabbage', 'shrimp', 'ounces', 'bean', 'sprouts', 'shelled', 'peanuts', 'red', 'chili', 'peppers', 'lime', 'wedges']

# %%
veggie = ['vegetable','vegetables','basil','basils','veggie','krapow','salad','salads','muchroom','tomato','tomatoes',
          'leaves','leaf','kimchi','onion','onions','vegan']
soup = ['boil','boiled','soup','stew']
seafood = ['shrimp','scallop','crab','oyster','prawn','salmon','squid','octopus','cutterfish','mussel','fish']
traditional = ['thai','korean','udontani','italy','italian']
street = ['grill','grilled','fry','fried','barbecue','roast','burger','burgers','cheese','egg']
sweet = ['sweet','flour','chocolate','egg','bread','ice','cream','cheese','pie','blueberry','strawberry']

# %%
list(set(filtered_sentence2).intersection(set(veggie)))
# Out:
# []

# %%
matching = [s for s in data2['likes'] if '5d2f19959b09d20d4cf4320f' in s]

# %%
matching
# Out:
# []

# %%
data[data['body'] == 'veggie'].count()
# Out:
# body     0
# likes    0
# title    0
# type     0
# dtype: int64

# %%
tagTable = ['title','body']
